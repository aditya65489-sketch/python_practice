# %%
x=100

# %%
type(x)
# Out:
# int

# %%
x=653*6542
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 4271926

# %%
x=3.14
type(x)
# Out:
# float

# %%
x="simplilearn"
print(x)
type(x)
# Out:
# simplilearn
# str

# %%
x=[14,34,56]
type(x)
# Out:
# list

# %%
print(x)
# Out:
# [14, 34, 56]

# %%
print(x[2])
# Out:
# 56

# %%
x[2]=65

# %%
print(x)
# Out:
# [14, 34, 65]

# %%
x= (4,9,12)
print(x)
# Out:
# (4, 9, 12)

# %%
type(x)
# Out:
# tuple

# %% [markdown]
# print(x[1])
# x[1]=5
# #tuples vairable is not changables

# %%
x=open('variable_com.ipynb' , 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 x=open('variable_com.ipynb' , 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'variable_com.ipynb'

# %% [markdown]
# type(x)

# %%
(x,y,z)= 5,21,26

# %%
print(x)
print(y)
print(z)

# %%
x=y=z=23

# %%
print(x,y,z)

# %% [markdown]
# # Rule for naming variable

# %%
abc=100
_abc=100

# %% [markdown]
# # Arthmatic operations

# %%
x=20
y=10

# %%
result=x+y
print(result)

# %%
result=x-y
print(result)

# %%
result=x*y
print(result)

# %%
result= x/y
print(result)

# %%
result=x//y
print(result)

# %%
result=x%y
print(result)

# %%
result=3%2
print(result)

# %%
x=3.14
y=5.7

# %%
result=x/y
print(result)

# %% [markdown]
# # string operations

# %%
var="simplilearn"

# %%
print(var[0])

# %%
print(var[0:4])

# %%
print(var[:4])

# %%
print(var[5:])

# %%
len(var)
