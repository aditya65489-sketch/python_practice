# %% [markdown]
# # sets and dicitionaries

# %% [markdown]
# # creating dictionaries

# %%
# d1={}
print(d1)
print(type(d1))
# Out:
# {}
# <class 'dict'>

# %%
d2={1:"welcome",2:"to",3:"python",4:"tutorial"}
print(d2)
# Out:
# {1: 'welcome', 2: 'to', 3: 'python', 4: 'tutorial'}

# %%
d3={"name":"sam","age":22,"profession":"student"}
print(d3)
# Out:
# {'name': 'sam', 'age': 22, 'profession': 'student'}

# %%
d4=dict({"name":"sam","age":22,"profession":"student"})
print(d4)
# Out:
# {'name': 'sam', 'age': 22, 'profession': 'student'}

# %%
d5=dict([(1,"welcome"),(2,"to"),(3,"python"),(4,"tutorial")])
print(d5)
# Out:
# {1: 'welcome', 2: 'to', 3: 'python', 4: 'tutorial'}

# %%
d6={"name":{"first":"sam","last":"mehta"},"age":22,"profession":"student"}
print(d6)
# Out:
# {'name': {'first': 'sam', 'last': 'mehta'}, 'age': 22, 'profession': 'student'}

# %% [markdown]
# # Adding element

# %%
d={}
d[0]="welcome"
print(d)
# Out:
# {0: 'welcome'}

# %%
d[1]=("how","are","you")
print(d)
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you')}

# %%
d["name"]="sam"
print(d)
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': 'sam'}

# %%
d["name"]={"first":"sam","last":"mehta"}
print(d)
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': {'first': 'sam', 'last': 'mehta'}}

# %% [markdown]
# # Accessing elements

# %%
print(d)
# Out:
# {}

# %%
print(d["name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 print(d["name"])
#
# KeyError: 'name'

# %%
print(d["name"]["first"])

# %%
print(d.get(1))

# %% [markdown]
# # Deleting elements

# %%
print(d)
# Out:
# {}

# %%
d.pop(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 d.pop(0)
#
# KeyError: 0

# %%
print(d)

# %%
d.popitem()

# %%
print(d)

# %%
print(d)

# %% [markdown]
# # Using built in functions

# %%
d.values()
# Out:
# dict_values([])

# %%
keys={'a','b','c','d'}
value=1
dict.fromkeys(keys,value)
# Out:
# {'b': 1, 'd': 1, 'a': 1, 'c': 1}

# %%
d.clear()

# %%
print(d)
# Out:
# {}

# %% [markdown]
# Sets

# %%
s=set([1,2,3,4])
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
s.add('a')

# %%
print(s)
# Out:
# {1, 2, 3, 4, 'a'}

# %%
fs=frozenset([1,2,3,4])
print(fs)
# Out:
# frozenset({1, 2, 3, 4})

# %%
fs.add("a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 fs.add("a")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s1=set([1,3,5,2])
s2=set([3,2,8,6])

# %%
s1.union(s2)

# %%
s1.difference(s2)
