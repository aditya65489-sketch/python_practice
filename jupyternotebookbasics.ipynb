# %% [markdown]
# print("Hello world")

# %%
print("hello")
# Out:
# hello

# %%
name =input("enter your name")
print("hi", name)
# Out:
# hi Aditya kumar choudhary

# %%
print("Hopem to see you in class")

# %% [markdown]
# this is a title
#
# #this is a bigger title

# %%
import matplotlib.pyplot as plt 

plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()
